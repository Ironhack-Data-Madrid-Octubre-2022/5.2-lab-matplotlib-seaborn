# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np

import pylab as plt
import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\data\Fitbit2.csv',encoding='latin1')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
import pylab as plt
# import matplotlib.pyplot as plt

import seaborn as sns

# %%
monthsmean=fitbit.groupby('Months_encoded')['Steps'].mean()
monthsmean
# Out:
# Months_encoded
# 1      9892.064516
# 2      8922.866667
# 3     10312.935484
# 4     13079.033333
# 5     10620.096774
# 6     12536.166667
# 7      9193.322581
# 8     11584.774194
# 9      9191.333333
# 10     8272.451613
# 11     9467.466667
# 12     8470.064516
# Name: Steps, dtype: float64

# %%
plt.plot(monthsmean);

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\monthsmean')#plt.SAVEFIG(r'ruta a la carpeta creada para guardar)

# %%
weekmean=fitbit.groupby('Work_or_Weekend')['Steps'].mean()#plt.plot(nombre_de_seleccion)
weekmean
# Out:
# Work_or_Weekend
# 0    10064.238095
# 1    10144.572519
# Name: Steps, dtype: float64

# %%
plt.plot(weekmean) #plt.plot(nombre_de_seleccion)

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\weekmean')

# %%
plt.xticks(rotation=35);
plt.rcParams['figure.figsize']=(15, 8)   # tamaño por defecto, decenas de pixeles

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %%
for i in fitbit.columns[6:9]: # Para el rango(lasa columnas en cuestion) iterar en el bucle de abajo
    fitbit.plot.scatter(x=i, y='Steps')

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\scrattersteps')

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
tit = pd.read_csv(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\data\titanic.csv',encoding='latin1')

# %%
tit
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
tit.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
tit.select_dtypes(include='number').head(10) # df.SELECT(INCLUDE = condicion)
# Out:
#    PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.000000      1      0   7.2500
# 1            2       1.0       1  38.000000      1      0  71.2833
# 2            3       1.0       3  26.000000      0      0   7.9250
# 3            4       1.0       1  35.000000      1      0  53.1000
# 4            5       0.0       3  35.000000      0      0   8.0500
# 5            6       0.0       3  23.926502      0      0   8.4583
# 6            7       0.0       1  54.000000      0      0  51.8625
# 7            8       0.0       3   2.000000      3      1  21.0750
# 8            9       1.0       3  27.000000      0      2  11.1333
# 9           10       1.0       2  14.000000      1      0  30.0708

# %%
tit.select_dtypes(exclude='number').head(10) # df.SELECT(EXCLUDE = condicion)
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S
# 5            330877    U0        Q
# 6             17463   E46        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.rcParams['figure.figsize']=(12, 6) # TAMAÑO DE LA FIGURA!!!!

# %%
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(tit.Age,kde=True);

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\edadtitanic')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.subplot(1,3,1), # plt.subplot()
sns.histplot(x=tit.Age,bins=10) # Histograma >>>> sns.histplot(x=data(o data.filtro), condiciones) <<<
    
plt.subplot(1,3,2),
sns.histplot(x=tit.Age,bins=20)

plt.subplot(1,3,3),
sns.histplot(x=tit.Age,bins=50)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\edadtitanic3')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
los bins dividen/sectorizan el grafico, cuanto mayor es su numero mas preciso es el valor de la barra
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(tit.Age,bins = 80,kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
sns.countplot(tit.Gender) # sns.countplot(df.columna)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\genedertitanic')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=tit.Pclass);

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\clasestitanic')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.axvline(tit.Age.mean(), # marcar una linea en el eje x = plot.AXVLINE(DF.COLUMNA.CONDICION())
c='r', # COLOR
linewidth=3., # GROSOR LINEA
linestyle='--', #ESTILO DE LINEA
label='mean') #TITULO

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\mediatitanic')

# %%
plt.axvline(tit.Age.median(), # marcar una linea en el eje x = plot.AXVLINE(DF.COLUMNA.CONDICION())
c='blue', # COLOR
linewidth=2., # GROSOR LINEA
linestyle='-.', #ESTILO DE LINEA
label='median') #TITULO

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\medianatitanic')

# %%
plt.axvline(tit.Age.mode(), # marcar una linea en el eje x = plot.AXVLINE(DF.COLUMNA.CONDICION())
c='yellow', # COLOR
linewidth=4., # GROSOR LINEA
linestyle='--', #ESTILO DE LINEA
label='moda') #TITULO
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 plt.axvline(tit.Age.mode(), # marcar una linea en el eje x = plot.AXVLINE(DF.COLUMNA.CONDICION())
#       2 c='yellow', # COLOR
#       3 linewidth=4., # GROSOR LINEA
#       4 linestyle='--', #ESTILO DE LINEA
#       5 label='moda')
#
# File ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2373, in axvline(x, ymin, ymax, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.axvline)
#    2372 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2373     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:801, in Axes.axvline(self, x, ymin, ymax, **kwargs)
#     799 # Strip away the units for comparison with non-unitized bounds.
#     800 xx, = self._process_unit_info([("x", x)], kwargs)
# ...

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
La franja de edad predominante estaba comprendida entre los 20 y los 30
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
sns.histplot(data =tit,x='Age', y='Fare', kde=True )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\edadestitanic')

# %%
sns.histplot(x='Age',y='Fare', data=tit)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
pd.plotting.scatter_matrix(tit._get_numeric_data(), figsize=(20, 10)); # pd.plotting.SCATTER_MATRIX(df._GET_NUMERIC_DATA(), FIGSIZE = (15,8))
#IMPORTANTE : añadir el figsize, si no da error

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\scatter_matrix')

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.histplot(data=tit, x='Pclass', y='Age' )
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\fareage')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.histplot(x=tit.Age, # SELECCION COLUMNA x = df.columns
hue=tit[(tit.Gender=='female')|(tit.Gender=='male')].Gender, # FILTRO >> df[(df.columna == condicion)& + filtros]
bins=80,
element='step')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.savefig(r'C:\Users\pablo\5.2-lab-matplotlib-seaborn\img\genderage')
