# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np

import pylab as plt

import seaborn as sns

import pandas as pd



import warnings
warnings.filterwarnings('ignore')

import pylab as plt

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit= pd.read_csv('../data/Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# Para la media de pasos/mes

df=fitbit.groupby('Months_encoded').mean()[['Steps']]

df.plot(kind='bar');

# %%
# Para la mediana de pasos/mes

df2=fitbit.groupby('Months_encoded').median()[['Steps']] 

df2.plot();

# %%
# Para la media de pasos/work or weekend

df3=fitbit.groupby('Work_or_Weekend').mean()[['Steps']]

sns.scatterplot(data=df3);

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
x=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']

for i in x:
    
    sns.scatterplot(data=fitbit, x=i, y=fitbit.Steps, color='y')
    
#No tengo claro si pide las tres juntas o cada una por separado del mismo loop.

# %%
sns.scatterplot(data=fitbit, x="Minutes Lightly Active", y='Steps');

# %%
sns.scatterplot(data=fitbit, x="Minutes Very Active", y='Steps', color='y');

# %%
sns.scatterplot(data=fitbit, x="Minutes Sedentary", y='Steps', color='g')
# Out:
# <AxesSubplot: xlabel='Minutes Sedentary', ylabel='Steps'>

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic= pd.read_csv('../data/titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 489.8 KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(['object']).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %%
# CATEGORICAL VARIABLES
titanic._get_numeric_data().head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
plt.rcParams['figure.figsize']=(12, 6)


# %matplotlib inline

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
x=titanic.Age

fig, axs = plt.subplots(1, 3, sharey=True, tight_layout=True, figsize=(12,6));
axs[0].hist(x, bins=10);
axs[1].hist(x, bins=20);
axs[2].hist(x, bins=50);

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# Delimita mejor/peor los grupos para hacer una vista más concreta o general, según lo que busques. Cuanto mayor sea el rango que escoges para la barra, agrupa más valores en ella y se pierde precisión; cuanto más pequeña es la barra, más preciso es pero se percibe mayor distribución

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here   

sns.displot(titanic.Age);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

df=titanic.groupby('Gender').agg({'Gender': 'count'})


df.plot.bar();

# %%
df
# Out:
#         Gender
# Gender
# female     466
# male       843

# %%
# Method 2 - seaborn

sns.countplot(x=titanic.Gender);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.Pclass);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x=titanic.Age,
             bins=50);   


plt.axvline(titanic.Age.mean(),
            c='r',
            linewidth=3.,
            linestyle='--',
            label='media de edad')

plt.axvline(titanic.Age.median(),
            c='orange',
            linewidth=3.,
            linestyle='--',
            label='mediana de edad')

plt.axvline(24,
            c='black',
            linewidth=3.,
            linestyle='--',
            label='moda de edad')

plt.title('Histograma de edades Titanic')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.legend()

plt.show();

# %%
print("Mediana: ",titanic.Age.median())
print("Media: ",titanic.Age.mean())
print("Moda: ",titanic.Age.mode())
# Out:
# Mediana:  28.5
# Media:  29.879185698255327
# Moda:  0    24.0
# Name: Age, dtype: float64

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %% [markdown]
# Que la mayor parte de los pasajeros eran jóvenes, entre 22-32 años con valores de media, moda y mediana muy cercanos, es decir, se acerca a la normalidad-.

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
s=sns.histplot(x=titanic.Age,
             bins=50,
            kde=True);   


plt.axvline(titanic.Age.mean(),
            c='r',
            linewidth=3.,
            linestyle='--',
            label='media de edad')

plt.axvline(titanic.Age.median(),
            c='orange',
            linewidth=3.,
            linestyle='--',
            label='mediana de edad')

plt.axvline(24,
            c='black',
            linewidth=3.,
            linestyle='--',
            label='moda de edad')

plt.title('Histograma de edades Titanic')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.legend()

plt.show();

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %% [markdown]
# La simetría de la distribución, si es normal o sesgada (positiva o negativamente). En este caso, es sesgo positivo donde moda < mediana < media.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
tit=titanic[['Fare', 'Age']]

# %%
corr=tit.corr(method='pearson')
corr
# Out:
#           Fare       Age
# Fare  1.000000  0.171355
# Age   0.171355  1.000000

# %%
# Method 1 - matplotlib

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f1daf_row0_col0, #T_f1daf_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f1daf_row0_col1, #T_f1daf_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f1daf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1daf_level0_col0" class="col_heading level0 col0" >Fare</th>
#       <th id="T_f1daf_level0_col1" class="col_heading level0 col1" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1daf_level0_row0" class="row_heading level0 row0" >Fare</th>
#       <td id="T_f1daf_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f1daf_row0_col1" class="data row0 col1" >0.171355</td>
#     </tr>
#     <tr>
#       <th id="T_f1daf_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_f1daf_row1_col0" class="data row1 col0" >0.171355</td>
# ...

# %%
# Method 2 - seaborn

sns.set(style='white')

cmap=sns.diverging_palette(0, 10, as_cmap=True)  

sns.heatmap(corr,

            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr=titanic.corr(method='pearson')


sns.set(style='white')    # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %% [markdown]
# Inversamente proporcionales, la clase con la tarifa (como era de esperar, ya que son mas caros cuanta mayor es la clase. Le sigue la clase con la edad, pero también inversamente proporcional. De forma proporcional, SibSp y Parch.

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

df=titanic.groupby('Pclass').agg({'Age': 'mean'})

df
# Out:
#               Age
# Pclass
# 1       39.555048
# 2       29.977433
# 3       25.432757

# %%
df.plot(kind='bar');

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
#No entiendo bien cómo hacerlo con Facetgrid pero de esta manera me parece visual por ambos lados.
sns.jointplot(x ='Gender', y ='Age', data = titanic, );
