# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd

import pylab as plt
# import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12, 4)   # tamaño por defecto, decenas de pixeles

import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv(r'C:\Users\david\Lab\5.2-lab-matplotlib-seaborn\data\Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fitbit.Months.unique()
# Out:
# array(['May', 'June', 'July', 'August', 'September', 'October',
#        'November', 'December', 'January', 'February', 'March', 'April'],
#       dtype=object)

# %%
# AVERAGE STEPS BY MONTH_ENCODED
ax=fitbit.groupby('Months_encoded').mean().Steps.plot(
        
        kind='bar',
        color=['y'],
        grid=True,
        figsize=(12, 8),
        title='Steps')

ax.set_xlabel('Month')
ax.set_ylabel('# Mean')

plt.show();

plt.savefig('fitbit1.png')

# %%
fitbit.Work_or_Weekend.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
ax=fitbit.groupby('Work_or_Weekend').mean().Steps.plot(
        
        kind='bar',
        color=['y'],
        grid=True,
        figsize=(12, 8),
        title='Steps')

ax.set_xlabel('Month')
ax.set_ylabel('# Mean')
#ax.set_xticks([1])
ax.set_xticklabels(['weekend','work'])

plt.show();

plt.savefig('fitbit2.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
lst = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for i in lst:
    sns.scatterplot(data=fitbit, x=i, y='Steps')

    plt.show();
    
plt.savefig('fitbit3.png')

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv(r'C:\Users\david\Lab\5.2-lab-matplotlib-seaborn\data\titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=[np.number]).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=[np.object]).columns
# Out:
# C:\Users\david\anaconda3\envs\clase\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
sns.set_style("darkgrid")

# %%
plt.subplots(figsize=(12, 6))
# Out:
# (<Figure size 1200x600 with 1 Axes>, <AxesSubplot:>)

# %%
from matplotlib import style
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %%
plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age,
             #element='step'  # contorno de la barra
            );

plt.savefig('titanic1.png')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
ig, x=plt.subplots(1, 3)    # pinta 1 fila 3 columnas, 3 plots en fila
plt.subplot(1,3,1)
sns.histplot(x=titanic.Age,
                 bins = 10
            );
plt.subplot(1,3,2)
sns.histplot(x=titanic.Age,
                 bins = 20
            );
plt.subplot(1,3,3)
sns.histplot(x=titanic.Age,
                 bins = 50
            );

plt.savefig('titanic2.png')

# %%
sns.histplot(x=titanic.Age,
             #element='step'  # contorno de la barra
             bins=10
            );

# %%
sns.histplot(x=titanic.Age,
             #element='step'  # contorno de la barra
             bins=20
            );

# %%
sns.histplot(x=titanic.Age,
             #element='step'  # contorno de la barra
             bins=50
            );

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Agrupa los datos en franjas de 'X' valores, lo que permite verlo con el detalle(agrupaciones) que queramos.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age,
             #element='step'  # contorno de la barra
            );

plt.savefig('titanic3.png')

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
# Method 1 - matplotlib

ax=titanic.groupby('Gender').count().Name.plot(
        
        kind='bar',
       
)

plt.show();

plt.savefig('titanic4.png')

# %%
# Method 2 - seaborn
sns.countplot(x=titanic.Gender,
             #element='step'  # contorno de la barra
            );

plt.savefig('titanic5.png')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic.Pclass.value_counts()

# %%
sns.countplot(x=titanic.Pclass,
             #element='step'  # contorno de la barra
            );

plt.savefig('titanic6.png')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic.Age.describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
titanic.Age.describe()[1:].plot.bar()

plt.savefig('titanic7.png')

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x=titanic.Age);
plt.axvline(titanic.Age.mean(), color="r", linestyle="--", label="Mean")
plt.axvline(titanic.Age.std(), color="r", linestyle="--", label="Std")
plt.axvline(titanic.Age.max(), color="r", linestyle="--", label="Max")
plt.axvline(titanic.Age.min(), color="r", linestyle="--", label="Min")

plt.savefig('titanic8.png')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic.Age, titanic.Fare);

plt.savefig('titanic9.png')

# %%
# Method 2 - seaborn
sns.scatterplot(data=titanic, 
                #hue='Genre', 
                x='Age',
                y='Fare');

plt.savefig('titanic10.png')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr(method='pearson')

# %%
sns.set(style='white')    # estilo blanco

#mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,
            #mask=mascara,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

plt.savefig('titanic11.png')

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(data=titanic, x='Pclass', y='Age');
plt.savefig('titanic12.png')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
titanic.Gender.unique()

# %%
sns.histplot(x=titanic.Age,
             #element='step'  # contorno de la barra
             hue=titanic[(titanic.Gender=='male') | (titanic.Gender=='female')].Gender
            );

plt.savefig('titanic13.png')

# %%
sns.histplot(x=titanic.Age, 
             
             hue=titanic[(titanic.Gender=='male') | (titanic.Gender=='female')].Gender,
             
             #bins=40,
             #element='step',  # contorno de las barras
             multiple='fill'   # normaliza, entre 0 y 1
            );
