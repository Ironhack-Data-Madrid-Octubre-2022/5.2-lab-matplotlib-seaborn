# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)   # mostrar todas las columnas del df
pd.set_option('display.max_rows', None)   # mostrar todas las filas del d
# Your Code Here

# %%
import pylab as plt

# %%
import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit = pd.read_csv('../data/fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED


plt.figure(figsize=(12, 4))

a =fitbit[['Months_encoded', 'Steps']].groupby('Months_encoded').mean().plot(

        kind='bar',
        figsize=(12, 4),
);


a.set_xlabel('meses')
a.set_ylabel('pasos')

a.set_xticklabels(['enero','febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre'])
plt.savefig('../figures/fitbit1.png')
plt.show();

# your code here

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND

plt.figure(figsize=(12, 4))

a =fitbit[['Work_or_Weekend', 'Steps']].groupby('Work_or_Weekend').mean().plot(

        kind='bar',
        figsize=(12, 4),
);


a.set_xlabel('meses')
a.set_ylabel('pasos')

a.set_xticklabels(['si','no'])
plt.savefig('../figures/fitbit2.png')
plt.show();


# your code here

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %%
# your code here


lista = ['Minutes Lightly Active', 'Minutes Fairly Active', 'Minutes Very Active']

for e in lista:
   

    sns.scatterplot(data=fitbit,  
                x=e,
                y='Steps');
    
    plt.show();

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic = pd.read_csv('../data/titanic.csv')

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(exclude='object').dtypes

# your code here
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include='object').dtypes

# your code here
# Out:
# Name        object
# Gender      object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

sns.set_style("whitegrid")
plt.rcParams['figure.figsize']=(12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(x=titanic.Age
             
            );

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here



fig, x=plt.subplots(1, 3)    # pinta 1 fila 3 columnas, 3 plots en fila

plt.subplot(1,3,1)
sns.histplot(x=titanic.Age,
                 bins = 10               
            );

plt.subplot(1,3,2)
sns.histplot(x=titanic.Age,
                 bins = 20                
            );

plt.subplot(1,3,3)
sns.histplot(x=titanic.Age,
                 bins = 50               
            );

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

#v el bins divide la información en más o menos barras
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(x=titanic.Age
             
            );

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib



titanic['Gender'].value_counts().plot.pie();


# your code here

# %%
# Method 2 - seaborn
labels = ['male','fmale']

plt.pie(titanic['Gender'].value_counts(), 
        labels = labels);

plt.show()
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.countplot(x=titanic.Pclass)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic.Age.describe().T
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
# your code here


sns.boxplot(data=titanic.Age, color='y',
            orient= 'h');

# %%
"""
your comments here

Para ver un resumen de todas las estadisticas para mi este plot es el más adecuado 
porque te da la mediana el rango intercuartil, los cuartiles 25 y 75, y minimo y máximo

"""
# Out:
# '\nyour comments here\n\nPara ver un resumen de todas las estadisticas para mi este plot es el más adecuado \nporque te da la mediana el rango intercuartil, los cuartiles 25 y 75, y minimo y máximo\n\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here

Pues la mediana de la edad es de unos 28 años
Que el rango de de edad está ente 0 - 80 años.

Y que la edad de la mitad de la gente es entre 22 y 37 
"""
# Out:
# '\nyour comments here\n\nPues la mediana de la edad es de unos 28 años\nQue el rango de de edad está ente 0 - 80 años.\n\nY que la edad de la mitad de la gente es entre 22 y 37 \n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.violinplot(data=titanic.Age,
              orient= 'h');

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here

La dsitribución de la edad. Podemos observar la moda en el pico de la curva. Sobre 27
"""
# Out:
# '\nyour comments here\n\nLa dsitribución de la edad. Podemos observar la moda en el pico de la curva. Sobre 27\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

titanic.plot.scatter(x="Age", y="Fare");

# your code here

# %%
# Method 2 - seaborn

sns.scatterplot(data=titanic,  
                x='Age',
                y='Fare');


# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr=titanic.corr(method='pearson')


sns.set(style='white')    # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

Pclass y Fare

"""
# Out:
# '\nyour comments here\n\nPclass y Fare\n\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(data=titanic, x="Age", y="Pclass",
            orient= 'h')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

sns.histplot(x=titanic.Age,
            hue = titanic['Gender']);
