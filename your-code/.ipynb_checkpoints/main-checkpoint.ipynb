# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import pylab as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv('../data/Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
steps_months = fitbit.groupby('Months_encoded').Steps.mean()
steps_months.plot()
# Out:
# <AxesSubplot:xlabel='Months_encoded'>

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
steps_work= fitbit.groupby('Work_or_Weekend').Steps.mean()
steps_work.plot()
# Out:
# <AxesSubplot:xlabel='Work_or_Weekend'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
for x in ['Minutes Lightly Active', 'Minutes Fairly Active', 'Minutes Very Active']:
    sns.scatterplot(data= fitbit, x='Steps', y=x)
    plt.show();

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(exclude=['object']).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=['object']).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.rcParams['figure.figsize']=(12, 6)
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age,
             bins=80,          # nº de barras 
             kde=True         # kde=kernel density estimation (la linea)
);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
for x in [10, 20, 50]:
    sns.histplot(data= titanic, x=titanic.Age, bins=x, color='#705202')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Cuanto más altos sean los 'bins', más años engloba la barra y hace una sumatoria de todos esos años
y por lo tanto los valores aumentan
"""
# Out:
# "\nCuanto más altos sean los 'bins', más años engloba la barra y hace una sumatoria de todos esos años\ny por lo tanto los valores aumentan\n"

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age,
             bins=80)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic.groupby('Gender').PassengerId.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
# Method 2 - seaborn
sns.countplot(titanic.Gender)
# Out:
# C:\Users\alvar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(titanic.Pclass)
# Out:
# C:\Users\alvar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic.Age.describe()[1:].plot.bar()
# Out:
# <AxesSubplot:>

# %%
"""
Retiramos la barra de 'Count' para poder ver los otros valores más claramente
"""
# Out:
# "\nRetiramos la barra de 'Count' para poder ver los otros valores más claramente\n"

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Nos da mucha información, como que la edad media de los pasageros del titanic rondaban los 30 años, así como la edad mínima y máxima
"""
# Out:
# '\nNos da mucha información, como que la edad media de los pasageros del titanic rondaban los 30 años, así como la edad mínima y máxima\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x=titanic.Age, bins=80)          

plt.axvline(x = titanic.Age.describe()['mean'], color = 'r', label = 'axvline - full height')
plt.axvline(x = titanic.Age.describe()['max'], color = 'r', label = 'axvline - full height')
plt.axvline(x = titanic.Age.describe()['min'], color = 'r', label = 'axvline - full height')
plt.axvline(x = titanic.Age.describe()['std'], color = 'r', label = 'axvline - full height')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Salen resultados congruentes
"""
# Out:
# '\nSalen resultados congruentes\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic.plot.scatter(x = 'Age', y = 'Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
# Method 2 - seaborn
sns.scatterplot(data=titanic, x='Age', y='Fare')

plt.show();

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr=titanic.corr(method='pearson')

sns.set(style='white')    # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Fare con Pclass
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.histplot(x = titanic.Age,
             hue= titanic.Pclass,
             bins=40)       # nº de barras
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.histplot(x = titanic.Age,
             hue= titanic.Gender,
             bins=40)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>
