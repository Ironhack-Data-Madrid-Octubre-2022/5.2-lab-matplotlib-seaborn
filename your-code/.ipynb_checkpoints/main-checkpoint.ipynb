# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import warnings
warnings.simplefilter('ignore')

import seaborn as sns
import pylab as plt
plt.rcParams['figure.figsize']=(15, 8)   # tamaño por defecto, decenas de pixeles
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit=pd.read_csv('../data/Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here
data = fitbit.groupby('Months_encoded').Steps.mean()
data.plot();

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
data = fitbit.groupby('Work_or_Weekend').Steps.mean()
data.plot.bar();

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
def plot(i):
    fig, ax=plt.subplots(1, 3)
    for t,g in enumerate(i):
        sns.scatterplot(data=fitbit,  
                        x=f'{g}',
                        y='Steps',
                       ax=ax[t]);

# %%
sp = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
plot(sp)

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv('../data/titanic.csv')

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 489.8 KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include = 'number').head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include = 'object').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.rcParams['figure.figsize']=(12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=titanic.Age,
             element='step'  # contorno de la barra
             
            );

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
def plot(i):
    fig, ax=plt.subplots(1, 3)
    for t,g in enumerate(i):
        sns.histplot(x=titanic.Age,
                     bins=g,          # nº de barras
                     kde=True,         # kde=kernel density estimation (la linea)
                     element='step',
                     fill=False,
                     ax=ax[t]
                    );

# %%
# your code here
plot([10, 20, 50])

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
cuantos más bins, mayor precisión a la hora de saber cuántos pasajeros por franja de edad
"""
# Out:
# '\ncuantos más bins, mayor precisión a la hora de saber cuántos pasajeros por franja de edad\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=titanic.Age,
             bins=40,
             element='step'  # contorno de la barra
            );

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic.groupby('Gender').PassengerId.count().plot.bar();

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x=titanic.Gender);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x=titanic.Pclass);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic.Age.describe()[1:].plot.bar();

# %%
"""
utilizaro un gráfico de barras, porque es más fácil comparar todas las estadísticas aquí. quitamos el count porque ensucia el gráfico.
"""
# Out:
# '\nutilizaro un gráfico de barras, porque es más fácil comparar todas las estadísticas aquí. quitamos el count porque ensucia el gráfico.\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
en general la mayor parte de los pasajeros se movían entre los 20 y 30 y pocos años de edad. Había algún pasajero muy mayor (80 años) y algún bebé.
"""
# Out:
# '\nyour comments here\nen general la mayor parte de los pasajeros se movían entre los 20 y 30 y pocos años de edad. Había algún pasajero muy mayor (80 años) y algún bebé.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.histplot(x=titanic.Age,
             bins = 40,
             element='step',# contorno de la barra
            )
plt.axvline(x = titanic.Age.describe()['mean'], color = 'g', label = 'mean')
plt.axvline(x = titanic.Age.describe()['25%'], color = 'r', label = 'mean')
plt.axvline(x = titanic.Age.describe()['75%'], color = 'b' ,label = 'mean')
plt.axvline(x = titanic.Age.describe()['max'], color = 'y', label = 'mean');

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
la mitad de los pasajeros se encontraban entre los early 20s y late 30s
"""
# Out:
# '\nyour comments here\nla mitad de los pasajeros se encontraban entre los early 20s y late 30s\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
# %matplotlib inline
plt.figure(figsize=(12,6))
plt.scatter(x=titanic["Age"], y=titanic["Fare"]);

# %%
# Method 2 - seaborn
# your code here
sns.regplot(x=titanic["Age"], y=titanic["Fare"])
plt.title('Age/Fare')
# Out:
# Text(0.5, 1.0, 'Age/Fare')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr=titanic.corr(method='pearson')
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
sns.set(style='white')    # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
Fare with Pclass
"""
# Out:
# '\nyour comments here\nFare with Pclass\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.histplot(x=titanic.Age, 
             hue=titanic.Pclass,
             bins=40,
            );

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col="Gender", size=5, aspect=1)
g.map(plt.hist, 'Age', alpha=.8, bins=20);
