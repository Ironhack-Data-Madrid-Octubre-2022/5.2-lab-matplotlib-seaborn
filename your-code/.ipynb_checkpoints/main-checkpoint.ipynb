# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# %pip install bar-chart-race
# Out:
# ...
#      |████████████████████████████████| 156 kB 6.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Libraries
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import numpy as np

import warnings
warnings.filterwarnings('ignore')

import bar_chart_race as bcr

import pandas as pd

from functools import reduce

import statistics as stat

import scipy.stats as st

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit.sample(n=11)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 279  2016-02-10            2662     99      7.43      21              1.237
# 53   2015-06-30            2945  12445      9.25      11            635.000
# 200  2015-11-24            2843  10261      7.62       1              1.182
# 201  2015-11-25            2829   8218      6.11      22              1.142
# 307  2016-03-09            3339  18092     14.05      19              1.120
# 166  2015-10-21            2406   4471      3.32       2              1.134
# 243  2016-01-06            2992  11327      8.42      14            613.000
# 62   2015-07-09            2994   7298      5.42       6            836.000
# 218  2015-12-12            2766   7157      5.32      11            605.000
# 330  2016-04-01            2814   1113      8.61       8            900.000
# 195  2015-11-19            3092  11927      8.86       9            726.000
#
# ...

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
plt.rcParams['figure.figsize']=(12, 4)

# %%
# AVERAGE STEPS BY MONTH_ENCODED

bymonth = fitbit.groupby('Months_encoded').agg({'Steps': 'mean'})
bymonth.plot();
plt.savefig('../figures/stepsxmonth.pdf')

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND

bywow = fitbit.groupby('Work_or_Weekend').agg({'Steps': 'mean'})
bywow.plot();
plt.savefig('../figures/stepsxweekend.pdf')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
for i in fitbit.columns[6:9]: # Para el rango(lasa columnas en cuestion) iterar en el bucle de abajo
    fitbit.plot.scatter(x=i, y='Steps')
    plt.savefig('../figures/comparison.pdf')

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1309.0   29.879186   13.448335  0.17   22.0000   28.5000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1309.0   33.281086   51.741500  0.00    7.8958   14.4542
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           37.000    80.0000
# SibSp          1.000     8.0000
# Parch          0.000     9.0000
# Fare          31.275   512.3292

# %%
# CATEGORICAL VARIABLES
titanic.describe(include='object').T
# Out:
#          count unique                   top  freq
# Name      1309   1307  Connolly, Miss. Kate     2
# Gender    1309      2                  male   843
# Ticket    1309    929              CA. 2343    11
# Cabin     1309    187                    U0  1014
# Embarked  1309      3                     S   916

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.rcParams['figure.figsize']=(12, 6)
sns.histplot(x=titanic.Age,
             bins=40,
             color='g',
             kde=True
             ); 
plt.savefig('../figures/vis_age.pdf')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.rcParams['figure.figsize']=(12, 6)
plt.subplot(1,3,1), # plt.subplot()
sns.histplot(x=titanic.Age,bins=10, color='r'); # Histograma >>>> sns.histplot(x=data(o data.filtro), condiciones) <<<
    
plt.subplot(1,3,2),
sns.histplot(x=titanic.Age, bins=20, color='y');

plt.subplot(1,3,3),
sns.histplot(x=titanic.Age, bins=50, color='r');
plt.savefig('../figures/age_subplot.pdf')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
plt.rcParams['figure.figsize']=(12, 6)
sns.histplot(x=titanic.Age, bins=50, color='b', kde=True);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.hist(titanic.Gender, align='mid');
plt.savefig('../figures/gender_mal?.pdf')

# %%
# Method 2 - seaborn
sns.countplot(titanic.Gender);
plt.savefig('../figures/bygender.pdf')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.Pclass);
plt.savefig('../figures/by$.pdf')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(data=titanic.Age, color='g');
plt.savefig('../figures/blox_age.pdf')

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
sns.barplot(x='Age',y='Fare', data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
# Method 2 - seaborn
sns.histplot(x='Age',y='Fare', data=titanic)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
pd.plotting.scatter_matrix(titanic._get_numeric_data(), figsize=(20, 10));

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.histplot(data=titanic, x='Pclass', y='Age' );

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.histplot(x=titanic.Age, # SELECCION COLUMNA x = df.columns
hue=titanic[(titanic.Gender=='female')|(titanic.Gender=='male')].Gender, # FILTRO >> df[(df.columna == condicion)& + filtros]
bins=100,
element='step');
plt.savefig('../figures/AgeByGender.pdf')
