# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
# Your Code Here
import pylab as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

plt.rcParams['figure.figsize']=(12, 4)

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

fitbit=pd.read_csv('../data/Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED

# your code here

avg_steps_month=fitbit.groupby('Months_encoded')['Steps'].mean()


plt.plot(avg_steps_month);

plt.savefig('../figures/avg_steps_month')

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here

avg_steps_weekend=fitbit.groupby('Work_or_Weekend')['Steps'].mean()

plt.plot(avg_steps_weekend);

plt.savefig('../figures/avg_steps_weekend')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

for i in fitbit.columns[6:9]:
    
    fitbit.plot.scatter(x=i, y='Steps')
    
plt.savefig('../figures/minutes_vs_steps')

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

titanic=pd.read_csv('../data/titanic.csv')

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES

# your code here
titanic.select_dtypes(include='number').head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(exclude='number').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

plt.rcParams['figure.figsize']=(12, 4)
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(x=titanic.Age,
             element='step'  # contorno de la barra
            );

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, ax=plt.subplots(1,3)    

plt.subplot(1,3,1)
sns.histplot(x=titanic.Age,
             bins=10);

plt.subplot(1,3,2)
sns.histplot(x=titanic.Age,
             bins=20);

plt.subplot(1,3,3)    
sns.histplot(x=titanic.Age,
             bins=50);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Afectan a la cantidad de barras que ogrece el gráfico. Es el número de barras que hay.
"""
# Out:
# '\nAfectan a la cantidad de barras que ogrece el gráfico. Es el número de barras que hay.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.kdeplot(x=titanic.Age,
            shade=True);
# Out:
# /Users/anachaparrohernandez/opt/anaconda3/envs/clase/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   after removing the cwd from sys.path.

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here


plt.pie(titanic.Gender.value_counts(), labels=['Male','Female'], autopct='%1.1f%%')
plt.title('Gender')
plt.axis('equal')
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.countplot(x=titanic.Gender, 
              
              palette='Blues')

plt.xticks(rotation=0);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.countplot(x=titanic.Pclass);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.histplot(x=titanic.Age,
             bins=40,
             element='step');   


plt.axvline(titanic.Age.mean(),
            c='r',
            linewidth=3.,
            linestyle='--',
            label='media de edad')

plt.axvline(titanic.Age.median(),
            c='orange',
            linewidth=3.,
            linestyle='--',
            label='mediana de edad')

plt.axvline(24,
            c='black',
            linewidth=3.,
            linestyle='--',
            label='moda de edad')

plt.title('Histograma de edades Titanic')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.legend()
plt.show();

# %%
"""
Un histograma.
"""
# Out:
# '\nUn histograma.\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Que la mayor parte de la gente que iba a bordo tenía entre 20 y 30 años.
"""
# Out:
# '\nQue la mayor parte de la gente que iba a bordo tenía entre 20 y 30 años.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.histplot(x=titanic.Age,
             bins=40,
             element='step',
             kde=True);   


plt.axvline(titanic.Age.mean(),
            c='r',
            linewidth=3.,
            linestyle='--',
            label='media de edad')

plt.axvline(titanic.Age.median(),
            c='orange',
            linewidth=3.,
            linestyle='--',
            label='mediana de edad')

plt.axvline(24,
            c='black',
            linewidth=3.,
            linestyle='--',
            label='moda de edad')

plt.title('Histograma de edades Titanic')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.legend()
plt.show();

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter(x='Age',
                y='Fare',
                data=titanic);

# %%
# Method 2 - seaborn
# your code here

sns.scatterplot(x='Age',
                y='Fare',
                data=titanic);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

pd.plotting.scatter_matrix(titanic._get_numeric_data(), figsize=(15, 8));

# %%
corr=titanic.corr(method='pearson')

# %%
sns.set(style='white')   
mascara=np.triu(np.ones_like(corr, dtype=bool))   
cmap=sns.diverging_palette(0, 10, as_cmap=True)   


sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Pclass y Fare.
"""
# Out:
# '\nPclass y Fare.\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(data=titanic, x='Pclass', y='Age' );

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.histplot(x=titanic.Age, 
             
             hue=titanic[(titanic.Gender=='male') | (titanic.Gender=='female')].Gender,
             
             bins=40,
             element='step');
