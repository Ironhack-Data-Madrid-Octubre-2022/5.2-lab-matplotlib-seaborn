# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import warnings
warnings.simplefilter('ignore')

import pandas as pd
import matplotlib.pyplot as plt

import pylab as plt
import seaborn as sns
import csv
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv( '../data/Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
mw=fitbit.groupby('Months_encoded')['Steps'].mean()
plt.plot(mw);

# %%
mediames=plt.plot(mw)
plt.savefig('graficos/mediames')

# %%
ww=fitbit.groupby('Work_or_Weekend')['Steps'].mean()
plt.plot(ww);

# %%
mediasem=plt.plot(ww)
plt.savefig('graficos/mediasem')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fig, ax = plt.subplots(1, 3)
for i,e in enumerate(fitbit.index[6:9]):
    fitbit.plot(ax=ax[i], x=e, y='Steps', kind='scatter');

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv( '../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
titanic.describe(include='object')
# Out:
#                         Name Gender    Ticket Cabin Embarked
# count                   1309   1309      1309  1309     1309
# unique                  1307      2       929   187        3
# top     Connolly, Miss. Kate   male  CA. 2343    U0        S
# freq                       2    843        11  1014      916

# %%
titanic.describe(include='number')
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.879186     0.498854
# std     378.020061    0.486592     0.837836    13.448335     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    22.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.500000     0.000000
# 75%     982.000000    1.000000     3.000000    37.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1309.000000
# mean      0.385027    33.281086
# std       0.865560    51.741500
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.rcParams['figure.figsize'] = (12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.Age.plot.hist();

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, ax = plt.subplots(3,1)
bins=[10,20,50]
for i,e in enumerate(bins):
    sns.histplot(ax=ax[i], x=titanic.Age,bins=e);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Cuantos menos bins tenemos, más se suman los valores y por lo tanto más info perdemos
"""
# Out:
# '\nCuantos menos bins tenemos, más se suman los valores y por lo tanto más info perdemos\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.kdeplot(data=titanic.Age);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
sns.countplot(x=titanic.Gender, palette='magma');

# %%
plt.pie(titanic.Gender.value_counts(),
        colors=['b', 'salmon'],
        shadow=True,
        startangle=90,
        autopct='%1.2f%%')



plt.title('Titanic por genero');

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.Pclass, palette='viridis' );

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x=titanic.Age, color='y');

# %%
"""
Con boxplot, porque da toda la información que necesitamos
"""
# Out:
# '\nCon boxplot, porque da toda la información que necesitamos\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Nos informa de:
-la media esta un poquito por debajo de los treinta años
-la gran mayoria de la gente tiene entre algo más de 20 y algo menos de 40 años
-la persona más mayor est en los 80 años
También informa de los outliers
"""
# Out:
# '\nNos informa de:\n-la media esta un poquito por debajo de los treinta años\n-la gran mayoria de la gente tiene entre algo más de 20 y algo menos de 40 años\n-la persona más mayor est en los 80 años\nTambién informa de los outliers\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.violinplot(data=titanic.Age, color='g');

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Mas o menos nos informa de lo mismo , lo único diferente es que en este aparecen os menores 
de 20 cosa que en otro pasaba desapercibida
"""
# Out:
# '\nMas o menos nos informa de lo mismo , lo único diferente es que en este aparecen os menores \nde 20 cosa que en otro pasaba desapercibida\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# %matplotlib inline

sns.scatterplot(data=titanic, x='Age', y='Fare', palette='inferno');

# %%
plt.scatter(data=titanic, x='Age', y='Fare');

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr=titanic.corr(method='pearson')

# %%
sns.set(style='white')    # estilo blanco

mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara

cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Fare con Pclass
"""
# Out:
# '\nFare con Pclass\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x=titanic.Pclass, y=titanic.Age);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.histplot(x=titanic.Age,
             hue=titanic[(titanic.Gender=='male') | (titanic.Gender=='female')].Gender,
             bins=40,
             element='step');
